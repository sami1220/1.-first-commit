# %% [markdown]
# <span style="font-size: 30px">Python 入門課題　折紙問題</span>

# %% [markdown]
# ## 【問題1】べき乗の算術演算子を使用した実装
#
# べき乗の算術演算子を使用したプログラムを作ってください。
#
# 雛形として紙を1回折った時の厚さを計算するコードを用意しました。
#
# これを43回折った時のコードに書き換えてください。
#
# ** 紙を1回折った時の厚さを計算するコード**
#
# THICKNESS = 0.00008
# folded_thickness = THICKNESS * 2
#
# print("厚さ： {}メートル".format(folded_thickness))

# %%
THICKNESS = 0.00008
folded_thickness = THICKNESS *2 * 43
print("紙を４３回折った時の厚さは{}です".format(folded_thickness))
# Out:
# 紙を４３回折った時の厚さは0.006880000000000001です

# %% [markdown]
# ## 【問題2】単位の変換
#
# 単位がメートルだと実感が湧きづらいので、◯◯万キロメートル に変換して表示させてください。
#
# サンプルとして ◯◯キロメートル に変換したコードを用意したので、参考にして取り組んでください。小数点以下は2桁まで表示されるように指定しています。
#
# 《サンプルコード》
# ＃　メートルをキロメートルに変換して小数点以下2桁で表示する
# print("厚さ： {:.2f}キロメートル".format(folded_thickness / 1000))
#
# 月までの距離はおよそ 384,400 km です。折った紙が月に届くかどうか確認してみましょう。

# %%
THICKNESS = 0.00008
folded_thickness = THICKNESS * 2 * 43
print("厚さ： {}メートル".format(folded_thickness / 10000))
# Out:
# 厚さ： 6.88e-07メートル

# %% [markdown]
# <span style="font-size: 25px">【問題3】for文を使用して作成</span>
#
# 次に、for文を使用したプログラムを作ってください。
#
#
# べき乗の算術演算子は使ってはいけません。算術演算子は四則演算（+、-、*、/）のみ使えます。

# %%
a = THICKNESS = 0.00008
folded_thickness = 43
graph = []
for i in range(int(folded_thickness-1)):
    THICKNESS *= a
    graph.append(THICKNESS)
print(THICKNESS)
print(graph)
# Out:
# 6.805647338418793e-177
# ...

# %% [markdown]
# ## 【問題4】計算時間の比較
#
# 以上の2つの方法はどちらも正しいですが、
#
# コードの良さを比較する際には例えば以下のような点で評価されます。
#
# 実行速度
# メモリの使用量
# 可読性
# 拡張性
# 再利用性
#
# 今回は実行速度を比較してみます。
#
# 以下の雛形を使用して、2つの方法の実行時間を出力して、比較してください。変数の定義や print 文など、どちらの方法でも使われている部分は除いた範囲の時間を比較してください。
#
# 《雛形
# import time
# start = time.time()
#
# ! ここに比較したいコードを貼り付ける
#
# elapsed_time = time.time() - start
# print("time : {}[s]".format(elapsed_time))
#
# time モジュールを用いることで時刻を取得できます。比較したい箇所の前後の時刻の差を計算することで、実行時間を求めることができます

# %%
# べき乗
import time
start = time.time()

THICKNESS = 0.00008
folded_thickness = THICKNESS ** 43

elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# time : 8.177757263183594e-05[s]

# %%
# for文
import time
start = time.time()

a = THICKNESS = 0.00008
folded_thickness = 43
for i in range(int(folded_thickness - 1)):
    THICKNESS *= a
# print(THICKNESS)

elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# time : 0.00019669532775878906[s]

# %%
# %%timeit

# べき乗

import time
start = time.time()

THICKNESS = 0.00008
folded_thickness = THICKNESS ** 43

elapsed_time = time.time() - start
# print("time : {}[s]".format(elapsed_time))
# Out:
# 354 ns ± 6.81 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %%timeit

# for文

import time
start = time.time()

a = THICKNESS = 0.00008
folded_thickness = 43
for i in range(int(folded_thickness - 1)):
    THICKNESS *= a
# print(THICKNESS)

elapsed_time = time.time() - start
# print("time : {}[s]".format(elapsed_time))
# Out:
# 1.98 µs ± 19.8 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# ## 【問題5】リストへの保存
#
# ここまでは43回折った後の最後の値だけを使用していましたが、グラフで可視化するためには過程の値も必要です。for文を使用したコードに、過程の値合計44個を記録するコードを加えてください。
#
# 《ヒント》
# まず、空のリストを作成する。
# 次に、折る前の値をリストに追加する。
# for文の中でn回までの紙を折る過程の値をリストに追加していく。
#
# 最終的にリストに44個の値が格納されていることを len 関数を用いて確認しておきましょう。

# %%
a = THICKNESS = 0.0008
folded_thickness = 43

graph = []
for i in range(int(folded_thickness - 1)):
    THICKNESS *= a
    graph.append(THICKNESS)
# print(THICKNESS)

# 回答
print(graph)
print(len(graph))
# Out:
# [6.4e-07, 5.12e-10, 4.096e-13, 3.2768000000000003e-16, 2.6214400000000003e-19, 2.0971520000000004e-22, 1.6777216000000003e-25, 1.3421772800000004e-28, 1.0737418240000004e-31, 8.589934592000003e-35, 6.871947673600003e-38, 5.497558138880003e-41, 4.3980465111040027e-44, 3.5184372088832023e-47, 2.814749767106562e-50, 2.2517998136852495e-53, 1.8014398509481997e-56, 1.4411518807585597e-59, 1.1529215046068478e-62, 9.223372036854782e-66, 7.378697629483826e-69, 5.902958103587061e-72, 4.72236648286965e-75, 3.77789318629572e-78, 3.022314549036576e-81, 2.4178516392292607e-84, 1.9342813113834086e-87, 1.5474250491067269e-90, 1.2379400392853815e-93, 9.903520314283052e-97, 7.922816251426442e-100, 6.338253001141154e-103, 5.070602400912923e-106, 4.0564819207303387e-109, 3.2451855365842713e-112, 2.5961484292674173e-115, 2.076918743413934e-118, 1.661534994731147e-121, 1.3292279957849177e-124, 1.0633823966279343e-127, 8.507059173023475e-131, 6.80564733841878e-134]
# 42

# %% [markdown]
# ## 【問題6】折れ線グラフの表示
#
# グラフの描画には Matplotlib という ライブラリ を用います。リストへ記録するコードの後ろで以下の雛形を使用してください。
#
# import matplotlib.pyplot as plt
# %matplotlib inline
# ! グラフを表示する。タイトルと軸ラベル名付き。
# plt.title("thickness of folded paper")
# plt.xlabel("number of folds")
# plt.ylabel("thickness [m]")
# plt.plot(リスト名)  # 「リスト名」のところにリストの変数名を入れる
# plt.show()

# %%
a = THICKNESS = 0.0008
folded_thickness = 43

graph = []
for i in range(int(folded_thickness - 1)):
    THICKNESS *= a
    graph.append(THICKNESS)
print(THICKNESS)
# print(graph)
print(len(graph))

import matplotlib.pyplot as plt
# %matplotlib inline
# グラフを表示する。タイトルと軸ラベル名付き。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(graph, color='skyblue', linestyle='solid', linewidth=3, markersize=12)
plt.show()
# Out:
# 6.80564733841878e-134
# 42

# %% [markdown]
# ## 【問題7】グラフのカスタマイズ
#
# グラフをより見やすくカスタマイズしてみましょう。カスタマイズしたグラフを最低3種類作成してください。例えば以下のように書き換えることで、線の色を赤に変更できます。
#
#
# 《サンプルコード》
#
# !赤い折れ線グラフを表示する。
# plt.title("thickness of folded paper")
# plt.xlabel("number of folds")
# plt.ylabel("thickness [m]")
# plt.plot(リスト名, color='red')
# plt.show()

# %%
a = THICKNESS = 0.0008
folded_thickness = 43

graph = []
for i in range(int(folded_thickness - 1)):
    THICKNESS *= a
    graph.append(THICKNESS)
print(THICKNESS)
# print(graph)
print(len(graph))

import matplotlib.pyplot as plt
# %matplotlib inline
# グラフを表示する。タイトルと軸ラベル名付き。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(graph, color='green')
plt.show()
# Out:
# 6.80564733841878e-134
# 42

# %%
a = THICKNESS = 0.0008
folded_thickness = 43

graph = []
for i in range(int(folded_thickness - 1)):
    THICKNESS *= a
    graph.append(THICKNESS)
print(THICKNESS)
# print(graph)
print(len(graph))

import matplotlib.pyplot as plt
# %matplotlib inline
# グラフを表示する。タイトルと軸ラベル名付き。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(graph, linestyle='dashed', color='gray')
plt.show()
# Out:
# 6.80564733841878e-134
# 42

# %%
a = THICKNESS = 0.0008
folded_thickness = 43

graph = []
for i in range(int(folded_thickness - 1)):
    THICKNESS *= a
    graph.append(THICKNESS)
print(THICKNESS)
# print(graph)
print(len(graph))

import matplotlib.pyplot as plt
# %matplotlib inline
# グラフを表示する。タイトルと軸ラベル名付き。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(graph, linestyle="dashdot", linewidth = 3.0, color="red")
plt.show()
# Out:
# 6.80564733841878e-134
# 42
